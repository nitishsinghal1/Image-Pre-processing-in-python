# %%
#to install skimage  use pip install scikit-image
from skimage import io,img_as_float
img=io.imread("ed_0.jpg",as_gray=True)

# %%
print(img.shape) #y,x,c
# Out:
# (444, 710)

# %%
print(img)
# Out:
# [[110 110 110 ... 122 122 122]
#  [110 110 110 ... 122 122 122]
#  [110 110 110 ... 122 122 122]
#  ...
#  [ 94  92  92 ...  84  83  78]
#  [ 94  96  98 ...  87  84  77]
#  [ 97 102 107 ...  91  87  79]]

# %%
print(io.imshow(img))
# Out:
# AxesImage(36.8,23.7639;379.442x253.436)

# %%
img2=img_as_float(img)

# %%
print(img2)
# Out:
# [[0.43137255 0.43137255 0.43137255 ... 0.47843137 0.47843137 0.47843137]
#  [0.43137255 0.43137255 0.43137255 ... 0.47843137 0.47843137 0.47843137]
#  [0.43137255 0.43137255 0.43137255 ... 0.47843137 0.47843137 0.47843137]
#  ...
#  [0.36862745 0.36078431 0.36078431 ... 0.32941176 0.3254902  0.30588235]
#  [0.36862745 0.37647059 0.38431373 ... 0.34117647 0.32941176 0.30196078]
#  [0.38039216 0.4        0.41960784 ... 0.35686275 0.34117647 0.30980392]]

# %%
from skimage import img_as_ubyte
img_8bit=img_as_ubyte(img2)

# %%
print(img_8bit)
# Out:
# [[110 110 110 ... 122 122 122]
#  [110 110 110 ... 122 122 122]
#  [110 110 110 ... 122 122 122]
#  ...
#  [ 94  92  92 ...  84  83  78]
#  [ 94  96  98 ...  87  84  77]
#  [ 97 102 107 ...  91  87  79]]

# %%
print(io.imshow(img_8bit))
# Out:
# AxesImage(36.8,23.7639;379.442x253.436)

# %%
#filtering
from skimage import filters
guassian_img=filters.gaussian(img,sigma=1)
print(guassian_img)
# Out:
# [[0.43139045 0.43139045 0.43139045 ... 0.47844878 0.47844928 0.47844928]
#  [0.43160271 0.43160271 0.43160271 ... 0.47866116 0.47866153 0.47866153]
#  [0.432569   0.432569   0.432569   ... 0.47962766 0.47962782 0.47962782]
#  ...
#  [0.37016889 0.36961707 0.37298422 ... 0.32867029 0.32545535 0.31784827]
#  [0.37502684 0.38024037 0.38838486 ... 0.33653374 0.32733462 0.31488968]
#  [0.38238928 0.39269658 0.40497655 ... 0.34545731 0.33267309 0.31749222]]

# %%
io.imsave("ed_0.jpg",guassian_img)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
from skimage import img_as_ubyte
guassian_img_8bit=img_as_ubyte(guassian_img)
io.imsave("saveed_image_8bit.tif",guassian_img_8bit)

# %%
! pip install opencv-python
#import cv2
# Out:
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.14.5 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.18.1)

# %%
import cv2

# %%
img_cv2=cv2.imread("720s.jpg")

# %%
print(img_cv2)
# Out:
# [[[ 20  71  51]
#   [ 18  69  49]
#   [ 13  66  46]
#   ...
#   [ 21  57  43]
#   [ 21  57  43]
#   [ 21  57  43]]
#
#  [[ 12  71  50]
#   [ 16  75  54]
#   [ 22  81  60]
#   ...
#   [ 19  55  41]
#   [ 19  55  41]
#   [ 19  55  41]]
#
#  [[  9  74  53]
#   [ 14  77  57]
#   [ 20  83  63]
#   ...
#   [ 19  54  40]
#   [ 19  54  40]
#   [ 19  54  40]]
#
#  ...
#
#  [[131 133 144]
#   [133 135 146]
#   [137 139 150]
#   ...
#   [142 150 167]
#   [142 150 167]
#   [141 149 166]]
#
#  [[129 131 142]
#   [131 133 144]
#   [134 136 147]
#   ...
#   [145 153 170]
#   [145 153 170]
#   [145 153 170]]
#
#  [[135 137 148]
#   [134 136 147]
#   [135 137 148]
#   ...
#   [143 151 168]
#   [143 151 168]
#   [144 152 169]]]

# %%
#Open cv reads image as BGR instead of RGB

# %%
# to read as gray image in open cv
grey_img=cv2.imread('720s.jpg',0)

# %%
print(grey_img)
# Out:
# [[ 59  57  54 ...  49  49  49]
#  [ 58  62  68 ...  47  47  47]
#  [ 60  64  70 ...  46  46  46]
#  ...
#  [136 138 142 ... 154 154 153]
#  [134 136 139 ... 157 157 157]
#  [140 139 140 ... 155 155 156]]

# %%
print(grey_img.shape)
# Out:
# (596, 900)

# %%
#for color image
color_img=cv2.imread("720s.jpg",1)

# %%
print(color_img)
# Out:
# [[[ 20  71  51]
#   [ 18  69  49]
#   [ 13  66  46]
#   ...
#   [ 21  57  43]
#   [ 21  57  43]
#   [ 21  57  43]]
#
#  [[ 12  71  50]
#   [ 16  75  54]
#   [ 22  81  60]
#   ...
#   [ 19  55  41]
#   [ 19  55  41]
#   [ 19  55  41]]
#
#  [[  9  74  53]
#   [ 14  77  57]
#   [ 20  83  63]
#   ...
#   [ 19  54  40]
#   [ 19  54  40]
#   [ 19  54  40]]
#
#  ...
#
#  [[131 133 144]
#   [133 135 146]
#   [137 139 150]
#   ...
#   [142 150 167]
#   [142 150 167]
#   [141 149 166]]
#
#  [[129 131 142]
#   [131 133 144]
#   [134 136 147]
#   ...
#   [145 153 170]
#   [145 153 170]
#   [145 153 170]]
#
#  [[135 137 148]
#   [134 136 147]
#   [135 137 148]
#   ...
#   [143 151 168]
#   [143 151 168]
#   [144 152 169]]]

# %%
print(color_img.shape)
# Out:
# (596, 900, 3)

# %%
cv2.imshow("pic_opencv2",img_cv2)
cv2.imshow("color pic from opencv",color_img)
cv2.imshow("gray pic from opencv",grey_img)
cv2.waitKey(0) # the value is in millisecs.if value is 0 then the windows will be open until they are closed
cv2.destroyAllWindows()

# %%
img_opencv=cv2.cvtColor(color_img,cv2.COLOR_BGR2RGB)

# %%
print(img_opencv)
# Out:
# [[[ 51  71  20]
#   [ 49  69  18]
#   [ 46  66  13]
#   ...
#   [ 43  57  21]
#   [ 43  57  21]
#   [ 43  57  21]]
#
#  [[ 50  71  12]
#   [ 54  75  16]
#   [ 60  81  22]
#   ...
#   [ 41  55  19]
#   [ 41  55  19]
#   [ 41  55  19]]
#
#  [[ 53  74   9]
#   [ 57  77  14]
#   [ 63  83  20]
#   ...
#   [ 40  54  19]
#   [ 40  54  19]
#   [ 40  54  19]]
#
#  ...
#
#  [[144 133 131]
#   [146 135 133]
#   [150 139 137]
#   ...
#   [167 150 142]
#   [167 150 142]
#   [166 149 141]]
#
#  [[142 131 129]
#   [144 133 131]
#   [147 136 134]
#   ...
#   [170 153 145]
#   [170 153 145]
#   [170 153 145]]
#
#  [[148 137 135]
#   [147 136 134]
#   [148 137 135]
#   ...
#   [168 151 143]
#   [168 151 143]
#   [169 152 144]]]

# %%
cv2.imwrite("saved_opencv.jpg",color_img)
# Out:
# True

# %%
img_Red=img_opencv[0,:,:]
print(img_Red)
print(img_Red.shape)
#similarly you can check for Green and Blue channels
# Out:
# [[51 71 20]
#  [49 69 18]
#  [46 66 13]
#  ...
#  [43 57 21]
#  [43 57 21]
#  [43 57 21]]
# (900, 3)

# %%
#for color image
color_img=cv2.imread("720s.jpg")

# %%
print(color_img)
# Out:
# [[[ 20  71  51]
#   [ 18  69  49]
#   [ 13  66  46]
#   ...
#   [ 21  57  43]
#   [ 21  57  43]
#   [ 21  57  43]]
#
#  [[ 12  71  50]
#   [ 16  75  54]
#   [ 22  81  60]
#   ...
#   [ 19  55  41]
#   [ 19  55  41]
#   [ 19  55  41]]
#
#  [[  9  74  53]
#   [ 14  77  57]
#   [ 20  83  63]
#   ...
#   [ 19  54  40]
#   [ 19  54  40]
#   [ 19  54  40]]
#
#  ...
#
#  [[131 133 144]
#   [133 135 146]
#   [137 139 150]
#   ...
#   [142 150 167]
#   [142 150 167]
#   [141 149 166]]
#
#  [[129 131 142]
#   [131 133 144]
#   [134 136 147]
#   ...
#   [145 153 170]
#   [145 153 170]
#   [145 153 170]]
#
#  [[135 137 148]
#   [134 136 147]
#   [135 137 148]
#   ...
#   [143 151 168]
#   [143 151 168]
#   [144 152 169]]]

# %%
#for color image
color_img=cv2.imread("example.tiff")

# %%
print(color_img)
# Out:
# [[[  2  85 215]
#   [  3  78 203]
#   [  4  70 188]
#   ...
#   [106 202 255]
#   [104 201 255]
#   [102 200 254]]
#
#  [[  3  84 215]
#   [  3  77 202]
#   [  2  70 186]
#   ...
#   [107 203 254]
#   [107 202 255]
#   [103 201 255]]
#
#  [[  4  85 214]
#   [  3  79 201]
#   [  4  70 187]
#   ...
#   [109 204 255]
#   [107 202 255]
#   [106 202 255]]
#
#  ...
#
#  [[ 39  85 139]
#   [ 40  86 140]
#   [ 40  85 140]
#   ...
#   [ 80 123 177]
#   [ 79 120 174]
#   [ 78 120 173]]
#
#  [[ 38  83 137]
#   [ 39  85 139]
#   [ 39  83 138]
#   ...
#   [ 79 120 174]
#   [ 77 119 171]
#   [ 77 118 170]]
#
#  [[ 37  83 137]
#   [ 40  84 138]
#   [ 37  83 136]
#   ...
#   [ 77 118 171]
#   [ 75 118 169]
#   [ 73 115 169]]]

# %%
print(color_img.shape)
# Out:
# (434, 650, 3)

# %%
img_tif=io.imread("example.tiff",as_gray=True)

# %%
print(img_tif)
# Out:
# [[0.41819882 0.38884314 0.35418196 ... 0.80918    0.80580902 0.80160471]
#  [0.41567608 0.38520431 0.3519498  ... 0.8114349  0.80946275 0.80552627]
#  [0.41793098 0.38998196 0.35334863 ... 0.81563922 0.80946275 0.80918   ]
#  ...
#  [0.36532706 0.36924863 0.36644314 ... 0.5151949  0.50399569 0.50287961]
#  [0.35776667 0.36532706 0.35888275 ... 0.50399569 0.49812471 0.49448588]
#  [0.35748392 0.36197098 0.35665059 ... 0.49531922 0.49308706 0.4841051 ]]

# %%
img1_tif=io.imread("example.tiff",as_gray=False)

# %%
print(img1_tif)
# Out:
# [[[215  85   2 255]
#   [203  78   3 255]
#   [188  70   4 255]
#   ...
#   [255 202 106 255]
#   [255 201 104 255]
#   [254 200 102 255]]
#
#  [[215  84   3 255]
#   [202  77   3 255]
#   [186  70   2 255]
#   ...
#   [254 203 107 255]
#   [255 202 107 255]
#   [255 201 103 255]]
#
#  [[214  85   4 255]
#   [201  79   3 255]
#   [187  70   4 255]
#   ...
#   [255 204 109 255]
#   [255 202 107 255]
#   [255 202 106 255]]
#
#  ...
#
#  [[139  85  39 255]
#   [140  86  40 255]
#   [140  85  40 255]
#   ...
#   [177 123  80 255]
#   [174 120  79 255]
#   [173 120  78 255]]
#
#  [[137  83  38 255]
#   [139  85  39 255]
#   [138  83  39 255]
#   ...
#   [174 120  79 255]
#   [171 119  77 255]
#   [170 118  77 255]]
#
#  [[137  83  37 255]
#   [138  84  40 255]
#   [136  83  37 255]
#   ...
#   [171 118  77 255]
#   [169 118  75 255]
#   [169 115  73 255]]]

# %%
# !pip install tifffile
# Out:
# Collecting tifffile
#   Downloading tifffile-2021.1.14-py3-none-any.whl (158 kB)
# Requirement already satisfied: numpy>=1.15.1 in c:\programdata\anaconda3\lib\site-packages (from tifffile) (1.18.1)
# Installing collected packages: tifffile
# Successfully installed tifffile-2021.1.14

# %%
import tifffile

# %%
img_tiff=tifffile.imread("example.tiff")

# %%
print(img_tiff)
# Out:
# [[[215  85   2 255]
#   [203  78   3 255]
#   [188  70   4 255]
#   ...
#   [255 202 106 255]
#   [255 201 104 255]
#   [254 200 102 255]]
#
#  [[215  84   3 255]
#   [202  77   3 255]
#   [186  70   2 255]
#   ...
#   [254 203 107 255]
#   [255 202 107 255]
#   [255 201 103 255]]
#
#  [[214  85   4 255]
#   [201  79   3 255]
#   [187  70   4 255]
#   ...
#   [255 204 109 255]
#   [255 202 107 255]
#   [255 202 106 255]]
#
#  ...
#
#  [[139  85  39 255]
#   [140  86  40 255]
#   [140  85  40 255]
#   ...
#   [177 123  80 255]
#   [174 120  79 255]
#   [173 120  78 255]]
#
#  [[137  83  38 255]
#   [139  85  39 255]
#   [138  83  39 255]
#   ...
#   [174 120  79 255]
#   [171 119  77 255]
#   [170 118  77 255]]
#
#  [[137  83  37 255]
#   [138  84  40 255]
#   [136  83  37 255]
#   ...
#   [171 118  77 255]
#   [169 118  75 255]
#   [169 115  73 255]]]

# %%
import numpy as np 
print(np.shape(img_tiff))
# Out:
# (434, 650, 4)

# %%
img_tiff_Red=img_tiff[0,:,:]

# %%
img_tiff_Green=img_tiff[1,:,:]

# %%
img_tiff_Blue=img_tiff[2,:,:]

# %%
print(img_tiff_Red)
# Out:
# [[215  85   2 255]
#  [203  78   3 255]
#  [188  70   4 255]
#  ...
#  [255 202 106 255]
#  [255 201 104 255]
#  [254 200 102 255]]

# %%
print(img_tiff_Blue)
# Out:
# [[214  85   4 255]
#  [201  79   3 255]
#  [187  70   4 255]
#  ...
#  [255 204 109 255]
#  [255 202 107 255]
#  [255 202 106 255]]

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (7.0.0)

# %%
# load and show an image with Pillow
from PIL import Image
from numpy import asarray
# Open the image form working directory
image = Image.open('720s.jpg')
# summarize some details about the image
print(image.format)
print(image.size)
print(image.mode)
# show the image
image.show()

# convert image to numpy array
data = asarray(image)
print(type(data))
# summarize shape
print(data.shape)


# create Pillow image
image2 = Image.fromarray(data)
print(type(image2))

# summarize image details
print(image2.mode)
print(image2.size)
# Out:
# JPEG
# (900, 596)
# RGB
# <class 'numpy.ndarray'>
# (596, 900, 3)
# <class 'PIL.Image.Image'>
# RGB
# (900, 596)

# %%
print(data)
# Out:
# [[[ 51  71  20]
#   [ 49  69  18]
#   [ 46  66  13]
#   ...
#   [ 43  57  21]
#   [ 43  57  21]
#   [ 43  57  21]]
#
#  [[ 50  71  12]
#   [ 54  75  16]
#   [ 60  81  22]
#   ...
#   [ 41  55  19]
#   [ 41  55  19]
#   [ 41  55  19]]
#
#  [[ 53  74   9]
#   [ 57  77  14]
#   [ 63  83  20]
#   ...
#   [ 40  54  19]
#   [ 40  54  19]
#   [ 40  54  19]]
#
#  ...
#
#  [[144 133 131]
#   [146 135 133]
#   [150 139 137]
#   ...
#   [167 150 142]
#   [167 150 142]
#   [166 149 141]]
#
#  [[142 131 129]
#   [144 133 131]
#   [147 136 134]
#   ...
#   [170 153 145]
#   [170 153 145]
#   [170 153 145]]
#
#  [[148 137 135]
#   [147 136 134]
#   [148 137 135]
#   ...
#   [168 151 143]
#   [168 151 143]
#   [169 152 144]]]

# %%
#Converting Images to Grayscale
import numpy as np
im = np.array(Image.open('720s.jpg').convert('L')) #you can pass multiple arguments in single line
print(im.shape)
print(type(im))

gr_im= Image.fromarray(im).save('720s.jpg')
print(gr_im)
# Out:
# (596, 900)
# <class 'numpy.ndarray'>
# None

# %%
#Resizing 
load_img_rz = np.array(Image.open('720s.jpg').resize((200,200)))
Image.fromarray(load_img_rz).save('720s.jpg')
print("After resizing:",load_img_rz.shape)
# Out:
# After resizing: (200, 200)

# %%
#trimming
im = np.array(Image.open('720s.jpg'))

print("Before trimming:",im.shape)

im_trim = im[128:384, 128:384]
print("After trimming:",im_trim.shape)

Image.fromarray(im_trim).save('trim_saltandpepper.jpg')
# Out:
# Before trimming: (200, 200)
# After trimming: (72, 72)

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
image = image.imread('720s.jpg')
print(image)
# summarize shape of the pixel array
print(image.dtype)
print(image.shape)
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# [[ 66  68  61 ...  51  48  45]
#  [ 50  51  49 ...  50  49  48]
#  [ 54  45  40 ...  40  41  41]
#  ...
#  [140 141 143 ... 128 118 111]
#  [142 142 143 ... 155 148 143]
#  [144 143 142 ... 159 158 158]]
# uint8
# (200, 200)

# %%
pyplot.imsave("saved_pyplot.jpg",image)
